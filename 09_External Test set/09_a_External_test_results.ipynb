# %%
import pandas as pd

# %%
df= pd.read_csv("New_test_244.csv")
df= df.rename(columns={"InChICode_standardised" : "StdInChI"})
df
# Out:
#                                               StdInChI  Activity  \
# 0    InChI=1S/C18H29N3O5/c1-18(2,3)19-11-15(22)12-8...       0.0
# 1    InChI=1S/C16H21NO2/c1-12(2)17-10-14(18)11-19-1...       0.0
# 2    InChI=1S/C9H7Cl2N5/c10-4-1-2-6(11)5(3-4)7-14-8...       0.0
# 3    InChI=1S/C34H54O8/c1-9-25(31-21(6)18-34(11-3,4...       1.0
# 4    InChI=1S/C20H21ClN2O4/c21-16-2-4-17(5-3-16)25-...       0.0
# ..                                                 ...       ...
# 239  InChI=1S/C19H24N2/c1-20(2)14-7-15-21-18-10-5-3...       1.0
# 240  InChI=1S/C20H23N/c1-21-14-6-12-20-13-11-15(16-...       1.0
# 241  InChI=1S/C24H34N4O5S/c1-4-21-17(3)15-28(22(21)...       1.0
# 242  InChI=1S/C25H31F3O5S/c1-5-20(31)33-25(21(32)34...       1.0
# 243  InChI=1S/C25H38O5/c1-6-25(4,5)24(28)30-21-12-1...       1.0
#
#                    Compound
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# ..                      ...
# 239              imipramine
# 240             Maprotiline
# 241             Glimepiride
# 242  fluticasone propionate
# 243             Simvastatin
#
# [244 rows x 3 columns]

# %%
#pred_CP_GO= pd.read_csv("Predicitions_for_CP_GO_Space_no_cell_death.csv")
pred_CP_GO= pd.read_csv("../Predicitions_for_CP_GO_Space_no_cell_deathv4.csv")
pred_CP_GO
# Out:
#                                                smiles_r  \
# 0     C/C=C/c1ccc2n(c1=O)C[C@H]1[C@@H]2N[C@@H](C(O)=...
# 1     C/C=C/c1ccc2n(c1=O)C[C@H]1[C@H](CO)[C@@H](C(=O...
# 2     C/C=C/c1ccc2n(c1=O)C[C@H]1[C@@H]2N(CCC(F)(F)F)...
# 3     C/C=C/c1ccc2n(c1=O)C[C@H]1[C@H](CO)[C@@H](C(=O...
# 4     C/C=C/c1ccc2n(c1=O)C[C@@H]1[C@@H](CO)[C@H](C(=...
# ...                                                 ...
# 9389                             NC(=O)c1ccc2[nH]ccc2c1
# 9390                              Cc1nc(O)c2cccc(O)c2n1
# 9391                           NC(=O)c1sc(-c2ccsc2)cc1N
# 9392                        N=C(N)N=C(O)Cc1c(Cl)cccc1Cl
# 9393                              c1cc(Cc2cnc[nH]2)ccn1
#
#                                                StdInChI  y_proba_CP_Model  \
# 0     InChI=1S/2C19H25N3O3/c2*1-2-4-11-7-8-15-16-13(...              0.25
# 1     InChI=1S/2C20H26F3N3O3/c2*1-4-5-12-6-7-15-16-1...              0.20
# 2     InChI=1S/2C20H26F3N3O3/c2*1-4-5-12-6-7-15-16-1...              0.39
# 3     InChI=1S/2C21H21FN2O6S/c2*1-2-5-12-8-9-15-19-1...              0.23
# 4     InChI=1S/2C21H21FN2O6S/c2*1-2-5-12-8-9-15-19-1...              0.20
# ...                                                 ...               ...
# 9389  InChI=1S/C9H8N2O/c10-9(12)7-1-2-8-6(5-7)3-4-11...              0.04
# 9390  InChI=1S/C9H8N2O2/c1-5-10-8-6(9(13)11-5)3-2-4-...              0.12
# 9391  InChI=1S/C9H8N2OS2/c10-6-3-7(5-1-2-13-4-5)14-8...              0.26
# 9392  InChI=1S/C9H9Cl2N3O/c10-6-2-1-3-7(11)5(6)4-8(1...              0.08
# 9393  InChI=1S/C9H9N3/c1-3-10-4-2-8(1)5-9-6-11-7-12-...              0.08
#
#       y_pred_CP_Model  y_proba_GO_Model  y_pred_GO_Model  \
# 0                   1              0.18                0
# 1                   1              0.09                0
# 2                   1              0.45                1
# 3                   1              0.12                0
# 4                   1              0.14                0
# ...               ...               ...              ...
# 9389                0              0.09                0
# 9390                0              0.24                1
# 9391                1              0.49                1
# 9392                0              0.07                0
# 9393                0              0.14                0
#
#       y_proba_Morgan_Model  y_pred_Morgan_Model  \
# 0                     0.17                    0
# 1                     0.25                    0
# 2                     0.25                    0
# 3                     0.10                    0
# 4                     0.10                    0
# ...                    ...                  ...
# 9389                  0.08                    0
# 9390                  0.19                    0
# 9391                  0.09                    0
# 9392                  0.14                    0
# 9393                  0.09                    0
#
#       y_proba_Early_Fusion_CP_GO_Model  y_pred_Early_Fusion_CP_GO_Model  \
# 0                                 0.15                                0
# 1                                 0.11                                0
# 2                                 0.35                                1
# 3                                 0.15                                0
# 4                                 0.19                                0
# ...                                ...                              ...
# 9389                              0.09                                0
# 9390                              0.09                                0
# 9391                              0.46                                1
# 9392                              0.07                                0
# 9393                              0.08                                0
#
#       y_proba_Early_Fusion_Morgan_CP  y_pred_Early_Fusion_Morgan_CP  \
# 0                               0.14                              0
# 1                               0.17                              1
# 2                               0.21                              1
# 3                               0.19                              1
# 4                               0.21                              1
# ...                              ...                            ...
# 9389                            0.04                              0
# 9390                            0.11                              0
# 9391                            0.21                              1
# 9392                            0.06                              0
# 9393                            0.07                              0
#
#       y_proba_Early_Fusion_CP_GO_Morgan_Model  \
# 0                                        0.13
# 1                                        0.11
# 2                                        0.30
# 3                                        0.12
# 4                                        0.20
# ...                                       ...
# 9389                                     0.12
# 9390                                     0.06
# 9391                                     0.32
# 9392                                     0.10
# 9393                                     0.09
#
#       y_pred_Early_Fusion_CP_GO_Morgan_Model  \
# 0                                          0
# 1                                          0
# 2                                          1
# 3                                          0
# 4                                          1
# ...                                      ...
# 9389                                       0
# 9390                                       0
# 9391                                       1
# 9392                                       0
# 9393                                       0
#
#       y_proba_Late_Stage_Fusion_CP_GO_Morgan_Model  \
# 0                                             0.13
# 1                                             0.11
# 2                                             0.30
# 3                                             0.12
# 4                                             0.20
# ...                                            ...
# 9389                                          0.12
# 9390                                          0.06
# 9391                                          0.32
# 9392                                          0.10
# 9393                                          0.09
#
#       y_pred_Late_Stage_Fusion_CP_GO_Morgan_Model
# 0                                               1
# 1                                               1
# 2                                               1
# 3                                               0
# 4                                               0
# ...                                           ...
# 9389                                            0
# 9390                                            1
# 9391                                            1
# 9392                                            0
# 9393                                            0
#
# [9394 rows x 16 columns]

# %%
merged=pd.merge(df, pred_CP_GO, how='inner', on=['StdInChI'])
#merged.to_csv("external_test_set.csv", index=False)
merged
# Out:
#                                               StdInChI  Activity  \
# 0    InChI=1S/C18H29N3O5/c1-18(2,3)19-11-15(22)12-8...       0.0
# 1    InChI=1S/C16H21NO2/c1-12(2)17-10-14(18)11-19-1...       0.0
# 2    InChI=1S/C9H7Cl2N5/c10-4-1-2-6(11)5(3-4)7-14-8...       0.0
# 3    InChI=1S/C34H54O8/c1-9-25(31-21(6)18-34(11-3,4...       1.0
# 4    InChI=1S/C20H21ClN2O4/c21-16-2-4-17(5-3-16)25-...       0.0
# ..                                                 ...       ...
# 239  InChI=1S/C19H24N2/c1-20(2)14-7-15-21-18-10-5-3...       1.0
# 240  InChI=1S/C20H23N/c1-21-14-6-12-20-13-11-15(16-...       1.0
# 241  InChI=1S/C24H34N4O5S/c1-4-21-17(3)15-28(22(21)...       1.0
# 242  InChI=1S/C25H31F3O5S/c1-5-20(31)33-25(21(32)34...       1.0
# 243  InChI=1S/C25H38O5/c1-6-25(4,5)24(28)30-21-12-1...       1.0
#
#                    Compound  \
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# ..                      ...
# 239              imipramine
# 240             Maprotiline
# 241             Glimepiride
# 242  fluticasone propionate
# 243             Simvastatin
#
#                                               smiles_r  y_proba_CP_Model  \
# 0     CN(C)C(=O)Oc1cc(OC(=O)N(C)C)cc(C(O)CNC(C)(C)C)c1              0.08
# 1                          CC(C)NCC(O)COc1cccc2ccccc12              0.11
# 2                N=c1nc(-c2cc(Cl)ccc2Cl)[nH]c(=N)[nH]1              0.07
# 3    CC[C@@H](C(=O)[C@@H](C)[C@@H](O)[C@H](C)CCc1cc...              0.63
# 4        O=C(COc1ccc(Cl)cc1)N1CCN(Cc2ccc3c(c2)OCO3)CC1              0.26
# ..                                                 ...               ...
# 239                      CN(C)CCCN1c2ccccc2CCc2ccccc21              0.21
# 240                    CNCCCC12CCC(c3ccccc31)c1ccccc12              0.24
# 241  CCC1=C(C)CN(C(O)=NCCc2ccc(S(=O)(=O)NC(O)=NC3CC...              0.08
# 242  CCC(=O)O[C@]1(C(=O)SCF)[C@H](C)C[C@H]2[C@@H]3C...              0.28
# 243  CCC(C)(C)C(=O)O[C@H]1C[C@@H](C)C=C2C=C[C@H](C)...              0.62
#
#      y_pred_CP_Model  y_proba_GO_Model  y_pred_GO_Model  y_proba_Morgan_Model  \
# 0                  0              0.10                0              0.100000
# 1                  0              0.42                1              0.100000
# 2                  0              0.17                0              0.060000
# 3                  1              0.66                1              0.231667
# 4                  1              0.17                0              0.070000
# ..               ...               ...              ...                   ...
# 239                1              0.06                0              0.066667
# 240                1              0.27                1              0.090000
# 241                0              0.12                0              0.090000
# 242                1              0.20                0              0.440000
# 243                1              0.22                0              0.050000
#
#      y_pred_Morgan_Model  y_proba_Early_Fusion_CP_GO_Model  \
# 0                      0                              0.05
# 1                      0                              0.25
# 2                      0                              0.15
# 3                      0                              0.62
# 4                      0                              0.18
# ..                   ...                               ...
# 239                    0                              0.14
# 240                    0                              0.36
# 241                    0                              0.09
# 242                    1                              0.27
# 243                    0                              0.61
#
#      y_pred_Early_Fusion_CP_GO_Model  y_proba_Early_Fusion_Morgan_CP  \
# 0                                  0                            0.06
# 1                                  1                            0.06
# 2                                  0                            0.05
# 3                                  1                            0.52
# 4                                  0                            0.16
# ..                               ...                             ...
# 239                                0                            0.25
# 240                                1                            0.16
# 241                                0                            0.06
# 242                                1                            0.20
# 243                                1                            0.51
#
#      y_pred_Early_Fusion_Morgan_CP  y_proba_Early_Fusion_CP_GO_Morgan_Model  \
# 0                                0                                     0.09
# 1                                0                                     0.22
# 2                                0                                     0.10
# 3                                1                                     0.63
# 4                                0                                     0.12
# ..                             ...                                      ...
# 239                              1                                     0.19
# 240                              0                                     0.20
# 241                              0                                     0.19
# 242                              1                                     0.26
# 243                              1                                     0.52
#
#      y_pred_Early_Fusion_CP_GO_Morgan_Model  \
# 0                                         0
# 1                                         1
# 2                                         0
# 3                                         1
# 4                                         0
# ..                                      ...
# 239                                       1
# 240                                       1
# 241                                       1
# 242                                       1
# 243                                       1
#
#      y_proba_Late_Stage_Fusion_CP_GO_Morgan_Model  \
# 0                                            0.09
# 1                                            0.22
# 2                                            0.10
# 3                                            0.63
# 4                                            0.12
# ..                                            ...
# 239                                          0.19
# 240                                          0.20
# 241                                          0.19
# 242                                          0.26
# 243                                          0.52
#
#      y_pred_Late_Stage_Fusion_CP_GO_Morgan_Model
# 0                                              0
# 1                                              1
# 2                                              0
# 3                                              1
# 4                                              1
# ..                                           ...
# 239                                            0
# 240                                            1
# 241                                            0
# 242                                            1
# 243                                            1
#
# [244 rows x 18 columns]

# %%
merged.Activity.value_counts()
# Out:
# 0.0    197
# 1.0     47
# Name: Activity, dtype: int64

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import average_precision_score
from sklearn.metrics import matthews_corrcoef,confusion_matrix, roc_auc_score, roc_curve
import matplotlib.pyplot as plt
from sklearn.metrics import f1_score
from sklearn.metrics import precision_score

# %%
from math import pi

# %%
y_true= merged["Activity"].to_numpy()


y_pred_list=["y_pred_CP_Model", "y_pred_GO_Model", "y_pred_Morgan_Model", "y_pred_Early_Fusion_CP_GO_Model",
            "y_pred_Early_Fusion_Morgan_CP", "y_pred_Early_Fusion_CP_GO_Morgan_Model",
            "y_pred_Late_Stage_Fusion_CP_GO_Morgan_Model"]

y_prob_list= ["y_proba_CP_Model", "y_proba_GO_Model", "y_proba_Morgan_Model", "y_proba_Early_Fusion_CP_GO_Model",
            "y_proba_Early_Fusion_Morgan_CP", "y_proba_Early_Fusion_CP_GO_Morgan_Model",
            "y_proba_Late_Stage_Fusion_CP_GO_Morgan_Model"]
models = ["CP Model", "GO Model", "Morgan Model", "Early Fusion CP+GO Model",
            "Early Fusion Morgan+CP", "Early Fusion CP+GO+Morgan Model",
            "Late Stage Fusion CP+GO+Morgan Model" ]

list_of_lists = []



for (i,j,k) in zip(y_pred_list, y_prob_list, models):
    
    print(k)
    
    y_prob = merged[j].to_numpy()
    y_pred = merged[i].to_numpy()
    
    
    
    conf_matrix = confusion_matrix(y_true, y_pred)
    print(conf_matrix)
    print(classification_report(y_true, y_pred))
    ba= balanced_accuracy_score(y_true, y_pred)
    print('balanced_accuracy_score ',ba)
    mcc=matthews_corrcoef(y_true, y_pred)
    print('matthews_corrcoef ',mcc)
            # Sensitivity, hit rate, recall, or true positive rate 
    Specificity = conf_matrix[0,0]/(conf_matrix[0,0]+conf_matrix[0,1])
            # Specificity or true negative rate
    Sensitivity = conf_matrix[1,1]/(conf_matrix[1,0]+conf_matrix[1,1]) 
    
    f1= f1_score(y_true, y_pred, average='binary')
    precision = precision_score(y_true, y_pred, average='binary')
    
    print('F1 Toxic', f1)
    print('Precision', precision)
    print('Sensitivity', Sensitivity)
    print('Specificity', Specificity)
    AUC = roc_auc_score(y_true, y_prob)
    print('AUC-ROC ',AUC)  
    AUCPR = average_precision_score(y_true, y_prob, average='weighted')
    print('AUCPR ',AUCPR) 
            # calculate roc curves
    best_model_fpr, best_model_tpr, _ = roc_curve(y_true, y_prob)   
    plt.plot(best_model_fpr, best_model_tpr, marker='.', label='Our Model')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.legend()
    plt.show()
    
    row=[ k, f1, precision, Sensitivity, Specificity, ba, mcc, AUC, AUCPR]
    list_of_lists.append(row)
# Out:
# CP Model
# [[ 94 103]
#  [ 13  34]]
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.48      0.62       197
#          1.0       0.25      0.72      0.37        47
#
#     accuracy                           0.52       244
#    macro avg       0.56      0.60      0.49       244
# weighted avg       0.76      0.52      0.57       244
#
# balanced_accuracy_score  0.6002808078626202
# matthews_corrcoef  0.1593960993081123
# F1 Toxic 0.3695652173913044
# Precision 0.24817518248175183
# Sensitivity 0.723404255319149
# Specificity 0.47715736040609136
# AUC-ROC  0.6260395291068149
# AUCPR  0.3639330074802284
# GO Model
# [[154  43]
#  [ 28  19]]
#               precision    recall  f1-score   support
#
#          0.0       0.85      0.78      0.81       197
#          1.0       0.31      0.40      0.35        47
#
#     accuracy                           0.71       244
#    macro avg       0.58      0.59      0.58       244
# weighted avg       0.74      0.71      0.72       244
#
# balanced_accuracy_score  0.5929906037369046
# matthews_corrcoef  0.16846883255525102
# F1 Toxic 0.34862385321100914
# Precision 0.3064516129032258
# Sensitivity 0.40425531914893614
# Specificity 0.7817258883248731
# AUC-ROC  0.6428880008640241
# AUCPR  0.38741752240772726
# Morgan Model
# [[180  17]
#  [ 38   9]]
#               precision    recall  f1-score   support
#
#          0.0       0.83      0.91      0.87       197
#          1.0       0.35      0.19      0.25        47
#
#     accuracy                           0.77       244
#    macro avg       0.59      0.55      0.56       244
# weighted avg       0.73      0.77      0.75       244
#
# balanced_accuracy_score  0.5525974727292364
# matthews_corrcoef  0.1344503676245144
# F1 Toxic 0.2465753424657534
# Precision 0.34615384615384615
# Sensitivity 0.19148936170212766
# Specificity 0.9137055837563451
# AUC-ROC  0.6456960794902258
# AUCPR  0.36204250445901104
# Early Fusion CP+GO Model
# [[158  39]
#  [ 26  21]]
#               precision    recall  f1-score   support
#
#          0.0       0.86      0.80      0.83       197
#          1.0       0.35      0.45      0.39        47
#
#     accuracy                           0.73       244
#    macro avg       0.60      0.62      0.61       244
# weighted avg       0.76      0.73      0.75       244
#
# balanced_accuracy_score  0.6244194837455448
# matthews_corrcoef  0.2278850820190653
# F1 Toxic 0.3925233644859813
# Precision 0.35
# Sensitivity 0.44680851063829785
# Specificity 0.8020304568527918
# AUC-ROC  0.6779889836915434
# AUCPR  0.4226040962872817
# Early Fusion Morgan+CP
# [[139  58]
#  [ 20  27]]
#               precision    recall  f1-score   support
#
#          0.0       0.87      0.71      0.78       197
#          1.0       0.32      0.57      0.41        47
#
#     accuracy                           0.68       244
#    macro avg       0.60      0.64      0.59       244
# weighted avg       0.77      0.68      0.71       244
#
# balanced_accuracy_score  0.6400259207257804
# matthews_corrcoef  0.2317994759091031
# F1 Toxic 0.4090909090909091
# Precision 0.3176470588235294
# Sensitivity 0.574468085106383
# Specificity 0.7055837563451777
# AUC-ROC  0.6796090290528135
# AUCPR  0.3813899647464613
# Early Fusion CP+GO+Morgan Model
# [[147  50]
#  [ 17  30]]
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.75      0.81       197
#          1.0       0.38      0.64      0.47        47
#
#     accuracy                           0.73       244
#    macro avg       0.64      0.69      0.64       244
# weighted avg       0.80      0.73      0.75       244
#
# balanced_accuracy_score  0.6922453828707205
# matthews_corrcoef  0.3229988963536808
# F1 Toxic 0.47244094488188976
# Precision 0.375
# Sensitivity 0.6382978723404256
# Specificity 0.7461928934010152
# AUC-ROC  0.6891672966843071
# AUCPR  0.4277536460581009
# Late Stage Fusion CP+GO+Morgan Model
# [[106  91]
#  [ 10  37]]
#               precision    recall  f1-score   support
#
#          0.0       0.91      0.54      0.68       197
#          1.0       0.29      0.79      0.42        47
#
#     accuracy                           0.59       244
#    macro avg       0.60      0.66      0.55       244
# weighted avg       0.79      0.59      0.63       244
#
# balanced_accuracy_score  0.6626525542715196
# matthews_corrcoef  0.2568851184835453
# F1 Toxic 0.42285714285714293
# Precision 0.2890625
# Sensitivity 0.7872340425531915
# Specificity 0.5380710659898477
# AUC-ROC  0.6891672966843071
# AUCPR  0.4277536460581009

# %%
df_results = pd.DataFrame(list_of_lists, columns=["Type", "F1 (Toxic)" , "Precision (Toxic)", "Sensitivity", "Specificity", "BA", "MCC" , "AUC", "AUCPR"])
df_results
# Out:
#                                    Type  F1 (Toxic)  Precision (Toxic)  \
# 0                              CP Model    0.369565           0.248175
# 1                              GO Model    0.348624           0.306452
# 2                          Morgan Model    0.246575           0.346154
# 3              Early Fusion CP+GO Model    0.392523           0.350000
# 4                Early Fusion Morgan+CP    0.409091           0.317647
# 5       Early Fusion CP+GO+Morgan Model    0.472441           0.375000
# 6  Late Stage Fusion CP+GO+Morgan Model    0.422857           0.289062
#
#    Sensitivity  Specificity        BA       MCC       AUC     AUCPR
# 0     0.723404     0.477157  0.600281  0.159396  0.626040  0.363933
# 1     0.404255     0.781726  0.592991  0.168469  0.642888  0.387418
# 2     0.191489     0.913706  0.552597  0.134450  0.645696  0.362043
# 3     0.446809     0.802030  0.624419  0.227885  0.677989  0.422604
# 4     0.574468     0.705584  0.640026  0.231799  0.679609  0.381390
# 5     0.638298     0.746193  0.692245  0.322999  0.689167  0.427754
# 6     0.787234     0.538071  0.662653  0.256885  0.689167  0.427754

# %%
df_results.to_csv("external_results.csv")
